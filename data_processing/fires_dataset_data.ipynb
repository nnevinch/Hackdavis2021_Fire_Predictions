# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/MyDrive/Hackdavis 2021/Data/Subset_Data_CA_WildFires_withCause.csv'
df = pd.read_csv(path)

# %%
df['DATE'] = pd.to_datetime(df['DISCOVERY_DATE'] - pd.Timestamp(0).to_julian_date(), unit='D')
print(df.head()) #check the data
print(df.columns)
#print(df[(df.DATE >= '2010-01-01') & (df.DATE <='2010-02-01')])
# Out:
#    OBJECTID  FIRE_YEAR  DISCOVERY_DATE  ...   LATITUDE   LONGITUDE       DATE
# 0   1067488       2010       2455335.5  ...  36.766944 -121.303056 2010-05-19
# 1   1067489       2010       2455355.5  ...  36.776944 -121.311111 2010-06-08
# 2   1067490       2010       2455359.5  ...  36.856111 -121.381111 2010-06-12
# 3   1067491       2010       2455361.5  ...  36.818056 -121.391111 2010-06-14
# 4   1067492       2010       2455388.5  ...  36.883056 -121.561944 2010-07-11
#
# [5 rows x 10 columns]
# Index(['OBJECTID', 'FIRE_YEAR', 'DISCOVERY_DATE', 'STAT_CAUSE_CODE',
#        'STAT_CAUSE_DESCR', 'FIRE_SIZE', 'FIRE_SIZE_CLASS', 'LATITUDE',
#        'LONGITUDE', 'DATE'],
#       dtype='object')

# %%
df_clean = df[['DATE', 'LATITUDE', 'LONGITUDE','FIRE_SIZE', 'FIRE_SIZE_CLASS', 'STAT_CAUSE_DESCR']]
csv_to_download = df_clean.to_csv('fire_data.csv')
from google.colab import files
files.download('fire_data.csv')
