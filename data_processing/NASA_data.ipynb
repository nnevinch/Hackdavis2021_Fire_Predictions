# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path1 = '/content/drive/MyDrive/Hackdavis 2021/Data/NASA data/20110101_20111231_Square1.csv'
df1 = pd.read_csv(path1, skiprows = 28)
path2 = '/content/drive/MyDrive/Hackdavis 2021/Data/NASA data/20120101_20121231_Square1.csv'
df2 = pd.read_csv(path2, skiprows = 28)
path3 = '/content/drive/MyDrive/Hackdavis 2021/Data/NASA data/20130101_20131231_Square1.csv'
df3 = pd.read_csv(path3, skiprows = 28)
path4 = '/content/drive/MyDrive/Hackdavis 2021/Data/NASA data/20140101_20141231_Square1.csv'
df4 = pd.read_csv(path4, skiprows = 28)
path5 = '/content/drive/MyDrive/Hackdavis 2021/Data/NASA data/20150101_20151231_Square1.csv'
df5 = pd.read_csv(path5, skiprows = 28)
path6 = '/content/drive/MyDrive/Hackdavis 2021/Data/NASA data/20110101_20111231_Square2.csv'
df6 = pd.read_csv(path6, skiprows = 28)
path7 = '/content/drive/MyDrive/Hackdavis 2021/Data/NASA data/20120101_20121231_Square2.csv'
df7 = pd.read_csv(path7, skiprows = 28)
path8 = '/content/drive/MyDrive/Hackdavis 2021/Data/NASA data/20130101_20131231_Square2.csv'
df8 = pd.read_csv(path8, skiprows = 28)
path9 = '/content/drive/MyDrive/Hackdavis 2021/Data/NASA data/20140101_20141231_Square2.csv'
df9 = pd.read_csv(path9, skiprows = 28)
path10 = '/content/drive/MyDrive/Hackdavis 2021/Data/NASA data/20150101_20151231_Square2.csv'
df10 = pd.read_csv(path10, skiprows = 28)
path11 = '/content/drive/MyDrive/Hackdavis 2021/Data/NASA data/20110101_20111231_Square3.csv'
df11 = pd.read_csv(path11, skiprows = 28)
path12 = '/content/drive/MyDrive/Hackdavis 2021/Data/NASA data/20120101_20121231_Square3.csv'
df12 = pd.read_csv(path12, skiprows = 28)
path13 = '/content/drive/MyDrive/Hackdavis 2021/Data/NASA data/20130101_20131231_Square3.csv'
df13 = pd.read_csv(path13, skiprows = 28)
path14 = '/content/drive/MyDrive/Hackdavis 2021/Data/NASA data/20140101_20141231_Square3.csv'
df14 = pd.read_csv(path14, skiprows = 28)
path15 = '/content/drive/MyDrive/Hackdavis 2021/Data/NASA data/20150101_20151231_Square3.csv'
df15 = pd.read_csv(path15, skiprows = 28)
path16 = '/content/drive/MyDrive/Hackdavis 2021/Data/NASA data/20110101_20111231_Square4.csv'
df16 = pd.read_csv(path16, skiprows = 28)
path17 = '/content/drive/MyDrive/Hackdavis 2021/Data/NASA data/20120101_20121231_Square4.csv'
df17 = pd.read_csv(path17, skiprows = 28)
path18 = '/content/drive/MyDrive/Hackdavis 2021/Data/NASA data/20130101_20131231_Square4.csv'
df18 = pd.read_csv(path18, skiprows = 28)
path19 = '/content/drive/MyDrive/Hackdavis 2021/Data/NASA data/20140101_20141231_Square4.csv'
df19 = pd.read_csv(path19, skiprows = 28)
path20 = '/content/drive/MyDrive/Hackdavis 2021/Data/NASA data/20150101_20151231_Square4.csv'
df20 = pd.read_csv(path20, skiprows = 28)
path21 = '/content/drive/MyDrive/Hackdavis 2021/Data/NASA data/20110101_20111231_Square5.csv'
df21 = pd.read_csv(path21, skiprows = 28)
path22 = '/content/drive/MyDrive/Hackdavis 2021/Data/NASA data/20120101_20121231_Square5.csv'
df22 = pd.read_csv(path22, skiprows = 28)
path23 = '/content/drive/MyDrive/Hackdavis 2021/Data/NASA data/20130101_20131231_Square5.csv'
df23 = pd.read_csv(path23, skiprows = 28)
path24 = '/content/drive/MyDrive/Hackdavis 2021/Data/NASA data/20140101_20141231_Square5.csv'
df24 = pd.read_csv(path24, skiprows = 28)
path25 = '/content/drive/MyDrive/Hackdavis 2021/Data/NASA data/20150101_20151231_Square5.csv'
df25 = pd.read_csv(path25, skiprows = 28)

# %%
frames = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19, df20, df21, df22, df23, df24, df25]
merged_df = pd.concat(frames)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-b0098c2fe043> in <module>()
#       1 frames = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19, df20, df21, df22, df23, df24, df25]
#       2 merged_df = pd.concat(frames)
# ----> 3 summary(merged_df)
#
# NameError: name 'summary' is not defined

# %%
print(merged_df.columns)
simplified_df = merged_df[['LAT', 'LON', 'YEAR', 'MO', 'DY', 'T2M_MAX', 'T2M_MIN', 'T2M', 'PRECTOT',
                          'RH2M', 'PS', 'WS10M_MIN', 'WS10M_MAX', 'WS10M' ]]
csv_to_download = simplified_df.to_csv('weather_data.csv')
from google.colab import files
files.download('weather_data.csv')
# Out:
# Index(['LAT', 'LON', 'YEAR', 'MO', 'DY', 'T2M_RANGE', 'TS', 'T2MDEW', 'T2MWET',
#        'T2M_MAX', 'T2M_MIN', 'T2M', 'PRECTOT', 'QV2M', 'RH2M', 'PS',
#        'WS50M_RANGE', 'WS10M_RANGE', 'WS50M_MIN', 'WS10M_MIN', 'WS50M_MAX',
#        'WS10M_MAX', 'WS50M', 'WS10M'],
#       dtype='object')
